# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pandas import read_csv
import json
from collections import defaultdict

# %%
frm = read_csv('./tabula-AD9174.csv')
frm
# Out:
#       Addr.           Name   Bits      Bit Name Settings  \
# 0     0x000  SPI_INTFCONFA      7   SOFTRESET_M      NaN
# 1       NaN            NaN      6    LSBFIRST_M      NaN
# 2       NaN            NaN      5     ADDRINC_M      NaN
# 3       NaN            NaN    NaN           NaN      NaN
# 4       NaN            NaN      4   SDOACTIVE_M      NaN
# ...     ...            ...    ...           ...      ...
# 3799    NaN        FTW31_2    NaN  FTW31[23:16]      NaN
# 3800    NaN            NaN    NaN           NaN      NaN
# 3801  0x881     DDSM_HOPF_  [7:0]    DDSM_HOPF_      NaN
# 3802    NaN        FTW31_3    NaN  FTW31[31:24]      NaN
# 3803    NaN            NaN    NaN           NaN      NaN
#
#                                             Description Reset Access
# 0     Soft reset (mirror). Set this bit to mirror Bi...   0x0      R
# 1     LSB first (mirror). Set this bit to mirror Bit 1.   0x0      R
# 2           Address increment (mirror). Set this bit to   0x0      R
# ...

# %%
def isStr(x):
    if type(x) is str and len(x) > 0:
        return x
    return None

def isInt(x):
    try:
        val = int(x, 16)
    except:
        val = None
    return val

# %%
regs = dict()
for i, f in frm.iterrows():
    if f['Addr.'] == 'Addr.':
        continue
        
    # Setup a new empty register entry if an address is found
    x = isInt(f['Addr.'])
    if x is not None:
        addr = x
        regs[addr] = {
            'name': '', 
            'bits': defaultdict(lambda: {'name': '', 'reset': None, 'description': ''})
        }
        
    x = isStr(f['Name'])
    if x is not None:
        regs[addr]['name'] += x

    x = isStr(f['Bits'])
    if x is not None:
        bit_key = x.replace('[', '').replace(']', '')
       
    x = isStr(f['Bit Name'])
    if x is not None:    
        regs[addr]['bits'][bit_key]['name'] += x
        
    x = isInt(f['Reset'])
    if x is not None:
        regs[addr]['bits'][bit_key]['reset'] = x
        
    x = isStr(f['Access'])
    if x is not None:    
        regs[addr]['bits'][bit_key]['access'] = x
        
    x = isStr(f['Description'])
    y = isStr(f['Settings'])
    if y is not None:
        x = y + ': ' + x
    if x is not None:
        if len(regs[addr]['bits'][bit_key]['description']) > 0:
            x = ' ' + x
        regs[addr]['bits'][bit_key]['description'] += x

# %%
with open('regs_ad9174.json', 'w') as f:
    json.dump(regs, f, indent=4)

# %% [markdown]
# # import

# %%
import json

# %%
with open('regs_ad9174.json') as f:
    regs = json.load(f)

# %%
reg_names = dict()
bit_names = dict()
for k, v in regs.items():
    if v['name'] == 'RESERVED':
        continue
    if v['name'] in reg_names:
        kk = reg_names[v['name']]
        print('reg {} ({:03x}) already exist ({:03x})'.format(v['name'], int(k), int(kk)))
    reg_names[v['name']] = k
    for bk, bv in v['bits'].items():
        if bv['name'] == 'RESERVED':
            continue
#         if bv['name'] in bit_names:
#             print('bit {} in {} already exist'.format(
#                 bv['name'], v['name']
#             ))
        bit_names[bv['name']] = (k, bk)
# Out:
# reg PLL_STATUS (7b5) already exist (281)

# %%
def adhelp(s):
    if s in bit_names:
        k, bit = bit_names[s]
    
    if type(s) is int:
        k = str(s)
        bit = None
    
    for bk, bv in regs[k]['bits'].items():
        if bit is None or bk == bit:    
            print('reg 0x{:03x} ({:s}), bit {:3s} ({:s}), {:3s}, 0x{:02x}\n{}\n'.format(
                int(k),
                regs[k]['name'],
                bk,
                bv['name'],
                bv['access'],
                bv['reset'],
                bv['description']
            ))

# %%
adhelp(33)
# Out:
# reg 0x021 (IRQ_ENABLE0), bit 7:4 (RESERVED), R  , 0x00
# Reserved.
#
# reg 0x021 (IRQ_ENABLE0), bit 3   (EN_DAC0_CAL_DONE), R/W, 0x00
# Enable DAC0 calibration complete interrupt.
#
# reg 0x021 (IRQ_ENABLE0), bit 2:1 (RESERVED), R/W, 0x00
# Reserved.
#
# reg 0x021 (IRQ_ENABLE0), bit 0   (EN_PAERR0), R/W, 0x00
# Enable PA protection error interrupt for DAC0.

# %%
def adhelp(s):
    for regk, regv in regs.items():
        regMatch = re.match(s, regv['name'])
        for bk, bv in regv['bits'].items():
            bitMatch = re.match(s, bv['name'])
            if regMatch or bitMatch:
                print('reg 0x{:03x} ({:s}), bit {:3s} ({:s}), {:3s}, 0x{:02x}\n{}\n'.format(
                    int(k),
                    regs[k]['name'],
                    bk,
                    bv['name'],
                    bv['access'],
                    bv['reset'],
                    bv['description']
                ))
